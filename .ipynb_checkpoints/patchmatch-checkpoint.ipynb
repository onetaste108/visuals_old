# %%
# %load_ext autoreload
# %autoreload 2
from patchmatch.patchmatch import PatchMatch
from img_utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
p = PatchMatch()

# %%
img1 = imload("data/me.jpg")
img1 = imsize(img1,(256,256))
imshow(img1)
img2 = imload("data/art2.jpg")
img2 = imsize(img2,(256,256))
imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x218447DE630>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x218447DED68>

# %%
p.match(img1,img2,3,1)
# Out:
# iter 0
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21844829208>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21844829390>
