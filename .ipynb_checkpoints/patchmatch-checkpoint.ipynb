# %%
# %load_ext autoreload
# %autoreload 2
from patchmatch.patchmatch import PatchMatch
from img_utils import *

# %%
img1 = imload("data/me.jpg")
img1 = imsize(img1,(256,256))
imshow(img1)
img2 = imload("data/mario.jpg")
img2 = imsize(img2,(256//1,256//1),mode=Image.ANTIALIAS)
imshow(img2)

# img1 = imload("data/me.jpg")
# img1 = imsize(img1,(5,5))
# imshow(img1)
# img2 = imload("data/m1.jpg")
# img2 = imsize(img2,(5,5),mode=Image.ANTIALIAS)
# imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x2447D037160>
# <PIL.Image.Image image mode=RGB size=64x64 at 0x2447D0379E8>

# %%
img2.shape
# Out:
# (64, 64, 3)

# %%
p = PatchMatch()

# %%
p.setup(img1,img2,3)

# %%
p.match(4)
# Out:
# 55122.22309194619
# 48964.198648397294
# 45869.25480500961
# 44066.707126914254
# <PIL.Image.Image image mode=RGB size=256x256 at 0x2447D034C50>
# <PIL.Image.Image image mode=L size=254x254 at 0x2447D0340F0>

# %%
imshow(p.best_vals)
