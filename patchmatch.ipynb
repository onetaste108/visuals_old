# %%
# %load_ext autoreload
# %autoreload 2
from patchmatch.patchmatch import PatchMatch
from img_utils import *

# %%
p = PatchMatch()

# %%
img1 = imload("data/me.jpg")
img1 = imsize(img1,(256,256))
imshow(img1)
img2 = imload("data/pickle.jpg")
img2 = imsize(img2,(256//1,256//1),mode=Image.ANTIALIAS)
imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1E593BFC518>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1E593BFC518>

# %%
p.match(img1,img2,3,4)
# Out:
# iter 0
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1E593B4F320>
# iter 1
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1E593B4F780>
# iter 2
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1E593B4F588>
# iter 3
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1E593B4F400>
