# %%
# %load_ext autoreload
# %autoreload 2
from patchmatch.patchmatch import PatchMatch
import img_utils as im
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img1 = im.load("data/ser.jpg")
img1 = im.size(img1,(512,512))
im.show(img1)

img2 = im.load("data/graf.jpg")
img2 = im.size(img2,(512,512))
im.show(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x188F1CDCEC8>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x188F1CDC048>

# %%
p = PatchMatch()
p.setup(img1,img2,20,20)

# %%
p.match(1)
# Out:
# .

# %%
im.show(p.get_best())
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x188F1CC1A88>
