# %%
# %load_ext autoreload
# %autoreload 2
from patchmatch.patchmatch import PatchMatch
from img_utils import *

# %%
img1 = imload("data/v3.jpg")
img1 = imsize(img1,(512,512))
imshow(img1)

img2 = imload("data/stol.jpg")
img2 = imsize(img2,(512,512))
imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x1E0534249B0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x1E0534249B0>

# %%
p = PatchMatch()
p.setup(img1,img2,20,20)

# %%
p.match(1)
# Out:
# 615347.1088

# %%
imshow(p.get_best())
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x1E0534AA278>
